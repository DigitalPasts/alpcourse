# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DigitalPasts/alpcourse/blob/main/notebooks/04_Vector_Space_Model_Egyptian.ipynb)

# %% [markdown]
# # Intro
#
# In this notebook, we explore a collection of ancient Akkadian and ancient Egyptian texts using the vector space model approach described by [Karsdorp et al. in the chapter "Exploring Texts using the Vector Space Model"](https://www.humanitiesdataanalysis.org/vector-space-model/notebook.html). By representing the texts as numeric vectors capturing word frequencies, we can quantify the lexical similarities and differences between corpora in each of these two ancient languages. The vector space model allows us to reason about texts spatially and apply geometric concepts like distance metrics to assess how "close" texts are to each other based on shared vocabulary.
#
# We preprocess the texts by tokenizing them into words, constructing a document-term matrix recording word frequencies per text, and analyzing the matrix using tools from the Python scientific computing stack, including NumPy, SciPy and Scikit-learn. Through techniques like tSNE (t-Distributed Stochastic Neighbor Embedding) and aggregation by text metadata like script type, language or genre, we explore patterns in the Akkadian and Egyptian corpora and showcase how the vector space model can yield quantitative insights into ancient textual data. The notebook serves as an example application of the concepts and methods covered in depth by Karsdorp et al. in their chapter.
#
# This notebook has been prepared by **Avital Romach** and is based on her research. It should be cited accordingly (see citation information at the bottom).

# %% [markdown]
# # Preprocessing the corpus

# %% [markdown]
# ## Imports

# %%
import os
import re
import numpy as np
import pandas as pd
import requests
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from scipy.spatial.distance import pdist, squareform
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import plotly.express as px

# %% [markdown]
# ## Functions

# %% [markdown]
# ### To upload corpus and metadata from GitHub

# %% [markdown]
# #### Functions and import for the **Akkadian** corpus
#
# The Akkadian corpus consists of a part of the _[Royal Inscriptions of the Neo-Assyrian Period (RINAP)](https://colab.research.google.com/drive/14hTZCg-9XyiireusajDQqc9k2GAbc82e#scrollTo=qUcbzacX0kJy&line=3&uniqifier=1)_, licensed CC-BY-SA, and was taken from Open Richely Annotated Cuneiform Corpus (ORACC).

# %%
def create_corpus_from_github_api(url):
  # URL on the Github where the csv files are stored
  github_url = url
  response = requests.get(github_url)

  corpus = []
  # Check if the request was successful
  if response.status_code == 200:
    files = response.json()
    for file in files:
      if file["download_url"][-3:] == "csv":
        corpus.append(pd.read_csv(file["download_url"], encoding="utf-8", index_col="Unnamed: 0").fillna(""))
        # For Egyptian adapt like this:
        #corpus.append(pd.read_csv(file["download_url"], encoding="utf-8").fillna(""))
  else:
    print('Failed to retrieve files:', response.status_code)

  return corpus

def get_metadata_from_raw_github(url):
  metadata = pd.read_csv(url, encoding="utf-8", index_col="Unnamed: 0").fillna("")
  return metadata

# %%
# Prepare Akkadian corpus (list of dataframes)

corpus = create_corpus_from_github_api('https://api.github.com/repos/DigitalPasts/ALP-course/contents/course_notebooks/data/rinap01')
corpus.extend(create_corpus_from_github_api('https://api.github.com/repos/DigitalPasts/ALP-course/contents/course_notebooks/data/rinap05'))

# %%
# Prepare Akkadian metadata
metadata = get_metadata_from_raw_github("https://raw.githubusercontent.com/DigitalPasts/ALP-course/master/course_notebooks/data/rinap1_5_metadata.csv")

# %% [markdown]
# #### Functions and import for the **Egyptian** corpus
#
# The Egyptian corpus is an extract of the database of the _[Thesaurus Linguae Aegyptiae (TLA)](https://thesaurus-linguae-aegyptiae.de)_, containing literary (and if you like: medical) texts. This export from the database is not published under a free license. Therefore, we access it from a private GitHub repository using an access token.

# %%
def create_corpus_from_private_github_api(url, token):
# URL on the Github where the csv files are stored
    headers = {
        "Authorization": f"token {token}"
    }
    github_url = url
    response = requests.get(github_url, headers=headers)

    dtype_dict = {"lemma_id": "str"}

    corpus = []
    # Check if the request was successful
    if response.status_code == 200:
        files = response.json() # Github API provides information about the data in the repository, e.g. the download_url
        for file in files:
            if file["download_url"][-3:] == "csv" or ".csv?token=" in file["download_url"]:
                corpus.append(pd.read_csv(file["download_url"], encoding="utf-8", sep = ',', dtype=dtype_dict).fillna(""))
    else:
        print('Failed to retrieve files:', response.status_code)

    return corpus

from io import StringIO

def get_metadata_from_raw_private_github(url, token):
    headers = {
        "Authorization": f"token {token}"
    }
    github_url = url
    response = requests.get(github_url, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        csv_data = StringIO(response.text)
        metadata = pd.read_csv(csv_data, encoding="utf-8", sep = ',', index_col="text_id").fillna("")
        return metadata
    else:
        raise Exception(f"Failed to retrieve metadata: {response.status_code}")

# %%
# only if corpus is not yet loaded
# Prepare Egyptian corpus (lists of dataframes)

#if False:

# NB: This token will expire at the end ot the year (2025)
tla_access_token = "github_pat_..." # to be added manually.

  ## TLA Literature
corpus = create_corpus_from_private_github_api('https://api.github.com/repos/thesaurus-linguae-aegyptiae/test-rawdata/contents/alp-course-2024/TLA_literature/erzaehlungen', tla_access_token)

corpus.extend(create_corpus_from_private_github_api('https://api.github.com/repos/thesaurus-linguae-aegyptiae/test-rawdata/contents/alp-course-2024/TLA_literature/reden', tla_access_token))

corpus.extend(create_corpus_from_private_github_api('https://api.github.com/repos/thesaurus-linguae-aegyptiae/test-rawdata/contents/alp-course-2024/TLA_literature/lehren', tla_access_token))

  ## TLA Medical
  #corpus = create_corpus_from_private_github_api('https://api.github.com/repos/thesaurus-linguae-aegyptiae/test-rawdata/contents/alp-course-2024/TLA_medical/TLA_pEbers', tla_access_token)

  #corpus.extend(create_corpus_from_private_github_api('https://api.github.com/repos/thesaurus-linguae-aegyptiae/test-rawdata/contents/alp-course-2024/TLA_medical/TLA_pEdwinSmith', tla_access_token))

# %%
# Egyptian metadata
metadata = get_metadata_from_raw_private_github("https://raw.githubusercontent.com/thesaurus-linguae-aegyptiae/test-rawdata/master/alp-course-2024/TLA_literature/TLA_metadata.csv", tla_access_token)

# %%
## Check if data is loaded
corpus[0].head()
# Out:
#                          text  line  word                          ref frag  \
# 0  2FPMTQIP45HI3LODGNIZFDO77I     1     2  IBUBdxQqwvMcu0CovD1Q5OKc7B8  […]
# 1  2FPMTQIP45HI3LODGNIZFDO77I     1     3  IBUBd1Mxn1WtEUULim1Z51mT3oc   qd
# 2  2FPMTQIP45HI3LODGNIZFDO77I     1     4  IBUBd9E0G7Z51UgbrcPup3GC3iY  […]
# 3  2FPMTQIP45HI3LODGNIZFDO77I     1     6  IBUBd9Ae0nMTckagsrRI5pGbPxQ  […]
# 4  2FPMTQIP45HI3LODGNIZFDO77I     1     7  IBUBd5FjpDQ83E60jslkgkHSx4Y  [•]
#
#   norm unicode_word lemma_id   cf    pos mask     sense inst reading  \
# 0  […]          […]
# 1   qd       𓐪𓂧𓏌𓏲𓁻𓑕   162450  qdd   VERB       schlafen
# 2  […]          […]
# 3  […]          […]
# 4    •            •             •  PUNCT
#
#    break_perc                    unicode  \
# 0         1.0                      ['…']
# 1         0.1  ['𓐪', '𓂧', '𓏌', '𓏲', '𓁻']
# 2         1.0                      ['…']
# 3         1.0                      ['…']
# 4         1.0                      ['•']
#
#                                                break
# 0                                        ['missing']
# 1  ['complete', 'complete', 'complete', 'complete...
# 2                                        ['missing']
# 3                                        ['missing']
# 4                                        ['missing']

# %%
# Prepare text_ids (list of unique ids), and metadata

text_ids = []
for text in corpus:
  text_ids.append(text["text"].iloc[0])


for id in text_ids:
  if id not in metadata.index:
    print(f"Text {id} missing from metadata")

metadata = metadata[metadata.index.isin(text_ids)]

metadata
# Out:
#                                                                     text_name  \
# text_id
# IMCRUSHSQ5HBHBGS3XQ2WYI3HM  pVandier = pLille 139 || Recto: Meryre und Sis...
# 2AT7OVM3PZDEDMYZVBIZGYAP44   pBrooklyn 47.218.135 || Brooklyner Weisheitstext
# 62AD3D3IY5EMTHDDJZ5UV42RWM  hintere Innenwand || Das Buch von der Himmelsk...
# EQTNMAUWUBDP5D7K2UJLHOZO5I                    hintere Innenwand || Rahmentext
# 5EGJISAVIVHCLJE2JUKHR23V6E                      linke Innenwand || Rahmentext
# ...                                                                       ...
# C6KGH3XC7RGU3DSL7HKYY2K3WM  pTurin CGT 54014, falsch CGT 54024 || Die Lehr...
# WOAIM6KKGJDJ5OUDFHRFJ542NM  01. tBerlin 8934 (tB) || Die Lehre des Ani (Ve...
# 2Z4GIGWZJVEMZO37R4ZP7RIARE  pChassinat II = pLouvre E 25352 || Die Geister...
# YWJMWQT65NDTPL6MPG6TLVJ5MI  03. pChassinat I = pLouvre E 25351 || Die Gesc...
# 4VLZLA44UVGJZN22WIWP774LOQ  Stele Louvre C 284 ("Bentresch-Stele") || Stel...
#
#                            corpus_manual  \
# text_id
# IMCRUSHSQ5HBHBGS3XQ2WYI3HM   Erzählungen
# 2AT7OVM3PZDEDMYZVBIZGYAP44        Lehren
# 62AD3D3IY5EMTHDDJZ5UV42RWM   Erzählungen
# EQTNMAUWUBDP5D7K2UJLHOZO5I   Erzählungen
# 5EGJISAVIVHCLJE2JUKHR23V6E   Erzählungen
# ...                                  ...
# C6KGH3XC7RGU3DSL7HKYY2K3WM        Lehren
# WOAIM6KKGJDJ5OUDFHRFJ542NM        Lehren
# 2Z4GIGWZJVEMZO37R4ZP7RIARE   Erzählungen
# YWJMWQT65NDTPL6MPG6TLVJ5MI   Erzählungen
# 4VLZLA44UVGJZN22WIWP774LOQ   Erzählungen
#
#                                                                          path  \
# text_id
# IMCRUSHSQ5HBHBGS3XQ2WYI3HM  sawlit || Literarische Texte || 1. Erzählungen...
# 2AT7OVM3PZDEDMYZVBIZGYAP44  sawlit || Literarische Texte || 3. Weisheitsle...
# 62AD3D3IY5EMTHDDJZ5UV42RWM  sawlit || Literarische Texte || 1. Erzählungen...
# EQTNMAUWUBDP5D7K2UJLHOZO5I  sawlit || Literarische Texte || 1. Erzählungen...
# 5EGJISAVIVHCLJE2JUKHR23V6E  sawlit || Literarische Texte || 1. Erzählungen...
# ...                                                                       ...
# C6KGH3XC7RGU3DSL7HKYY2K3WM  sawlit || Literarische Texte || 3. Weisheitsle...
# WOAIM6KKGJDJ5OUDFHRFJ542NM  sawlit || Literarische Texte || 3. Weisheitsle...
# 2Z4GIGWZJVEMZO37R4ZP7RIARE  sawlit || Literarische Texte || 1. Erzählungen...
# YWJMWQT65NDTPL6MPG6TLVJ5MI  sawlit || Literarische Texte || 1. Erzählungen...
# 4VLZLA44UVGJZN22WIWP774LOQ  sawlit || Literarische Texte || 1. Erzählungen...
#
#                            dateEarliest dateLatest      language_manual  \
# text_id
# IMCRUSHSQ5HBHBGS3XQ2WYI3HM                                Frühdemotisch
# 2AT7OVM3PZDEDMYZVBIZGYAP44                                Frühdemotisch
# 62AD3D3IY5EMTHDDJZ5UV42RWM                              Mittelägyptisch
# EQTNMAUWUBDP5D7K2UJLHOZO5I                              Mittelägyptisch
# 5EGJISAVIVHCLJE2JUKHR23V6E                              Mittelägyptisch
# ...                                 ...        ...                  ...
# C6KGH3XC7RGU3DSL7HKYY2K3WM                              Mittelägyptisch
# WOAIM6KKGJDJ5OUDFHRFJ542NM                                 Neuägyptisch
# 2Z4GIGWZJVEMZO37R4ZP7RIARE                          Traditionsägyptisch
# YWJMWQT65NDTPL6MPG6TLVJ5MI                          Traditionsägyptisch
# 4VLZLA44UVGJZN22WIWP774LOQ                          Traditionsägyptisch
#
#                                                    tlaTextLangName  \
# text_id
# IMCRUSHSQ5HBHBGS3XQ2WYI3HM                           Frühdemotisch
# 2AT7OVM3PZDEDMYZVBIZGYAP44                           Frühdemotisch
# 62AD3D3IY5EMTHDDJZ5UV42RWM  frühes und klassisches Mittelägyptisch
# EQTNMAUWUBDP5D7K2UJLHOZO5I  frühes und klassisches Mittelägyptisch
# 5EGJISAVIVHCLJE2JUKHR23V6E  frühes und klassisches Mittelägyptisch
# ...                                                            ...
# C6KGH3XC7RGU3DSL7HKYY2K3WM          traditionelles Mittelägyptisch
# WOAIM6KKGJDJ5OUDFHRFJ542NM          traditionelles Mittelägyptisch
# 2Z4GIGWZJVEMZO37R4ZP7RIARE          traditionelles Mittelägyptisch
# YWJMWQT65NDTPL6MPG6TLVJ5MI          traditionelles Mittelägyptisch
# 4VLZLA44UVGJZN22WIWP774LOQ          traditionelles Mittelägyptisch
#
#                                        tlaTextScriptName  \
# text_id
# IMCRUSHSQ5HBHBGS3XQ2WYI3HM   Späthieratische Buchschrift
# 2AT7OVM3PZDEDMYZVBIZGYAP44   Späthieratische Buchschrift
# 62AD3D3IY5EMTHDDJZ5UV42RWM  reguläre Hieroglyphenschrift
# EQTNMAUWUBDP5D7K2UJLHOZO5I  reguläre Hieroglyphenschrift
# 5EGJISAVIVHCLJE2JUKHR23V6E  reguläre Hieroglyphenschrift
# ...                                                  ...
# C6KGH3XC7RGU3DSL7HKYY2K3WM    Neuhieratische Buchschrift
# WOAIM6KKGJDJ5OUDFHRFJ542NM   Späthieratische Buchschrift
# 2Z4GIGWZJVEMZO37R4ZP7RIARE   Späthieratische Buchschrift
# YWJMWQT65NDTPL6MPG6TLVJ5MI   Späthieratische Buchschrift
# 4VLZLA44UVGJZN22WIWP774LOQ  reguläre Hieroglyphenschrift
#
#                                                                  contributors
# text_id
# IMCRUSHSQ5HBHBGS3XQ2WYI3HM  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'J...
# 2AT7OVM3PZDEDMYZVBIZGYAP44  ['Peter Dils', 'Altägyptisches Wörterbuch', 'L...
# 62AD3D3IY5EMTHDDJZ5UV42RWM  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'J...
# EQTNMAUWUBDP5D7K2UJLHOZO5I  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'J...
# 5EGJISAVIVHCLJE2JUKHR23V6E  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'B...
# ...                                                                       ...
# C6KGH3XC7RGU3DSL7HKYY2K3WM  ['Peter Dils', 'Altägyptisches Wörterbuch', 'B...
# WOAIM6KKGJDJ5OUDFHRFJ542NM  ['Peter Dils', 'Altägyptisches Wörterbuch', 'J...
# 2Z4GIGWZJVEMZO37R4ZP7RIARE  ['Peter Dils', 'Altägyptisches Wörterbuch', 'F...
# YWJMWQT65NDTPL6MPG6TLVJ5MI  ['Peter Dils', 'Altägyptisches Wörterbuch', 'F...
# 4VLZLA44UVGJZN22WIWP774LOQ  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'J...
#
# [209 rows x 9 columns]

# %% [markdown]
# ### To convert dataframe to string

# %% [markdown]
# This is necessary because `TfidfVectorizer` that we will use to do the tf-idf calculations requires a list of strings as input. Each string is an entire text (document).
#
# **Function to split the text dataframes according to a column**. Used to separate text to lines:
# * param df: dataframe containing one word in each row.
# * param column: the column by which to split the dfs, perferably `text` or `line`.
# * return: a list of dataframes split according to the value given to the column parameter.

# %%
def split_df_by_column_value(df, column):

    dfs = []
    column_values = df[column].unique()
    for value in column_values:
        split_df = df[df[column]==value]
        dfs.append(split_df)
    return dfs

# %%
split_df_by_column_value(corpus[0].head(), "line")
# Out:
# [                         text  line  word                          ref frag  \
#  0  2FPMTQIP45HI3LODGNIZFDO77I     1     2  IBUBdxQqwvMcu0CovD1Q5OKc7B8  […]
#  1  2FPMTQIP45HI3LODGNIZFDO77I     1     3  IBUBd1Mxn1WtEUULim1Z51mT3oc   qd
#  2  2FPMTQIP45HI3LODGNIZFDO77I     1     4  IBUBd9E0G7Z51UgbrcPup3GC3iY  […]
#  3  2FPMTQIP45HI3LODGNIZFDO77I     1     6  IBUBd9Ae0nMTckagsrRI5pGbPxQ  […]
#  4  2FPMTQIP45HI3LODGNIZFDO77I     1     7  IBUBd5FjpDQ83E60jslkgkHSx4Y  [•]
#
#    norm unicode_word lemma_id   cf    pos mask     sense inst reading  \
#  0  […]          […]
#  1   qd       𓐪𓂧𓏌𓏲𓁻𓑕   162450  qdd   VERB       schlafen
#  2  […]          […]
#  3  […]          […]
#  4    •            •             •  PUNCT
#
#     break_perc                    unicode  \
#  0         1.0                      ['…']
#  1         0.1  ['𓐪', '𓂧', '𓏌', '𓏲', '𓁻']
#  2         1.0                      ['…']
#  3         1.0                      ['…']
#  4         1.0                      ['•']
#
#                                                 break
#  0                                        ['missing']
#  1  ['complete', 'complete', 'complete', 'complete...
#  2                                        ['missing']
#  3                                        ['missing']
#  4                                        ['missing']  ]

# %% [markdown]
# **Function to convert the values from the text dataframe to a string of text with or without line breaks and word segmentation**.
# * param df: the text dataframe
# * param column: the chosen column from the dataframe to construct the text from (preferably unicode_word, cf, or lemma)
# * param break_perc: a parameter which dictates whether to include broken words depending on the percentage of how broken they are.
#                        Compares this value to the `break_perc` column in the dataframe.
#                        Parameter is set to 1 (i.e. all words, whether broken or not, are included); can be any float between 0 and 1.
# * param mask: boolean whether to mask named entities or not; set to True.
# * return: a string which includes all the words in the texts according to the column chosen. Extra spaces that were between broken words or empty lines are removed.

# %%
def df2str(df, column, break_perc=1, mask=True, segmentation=True):

    # check if column exists in dataframe. If not, return empty text.
    if column not in df.columns:
        return ("", 0, 0)
    else:
        # remove rows that include duplicate values for compound words
        if column not in ["norm", "cf", "sense", "pos"]:
            df = df.drop_duplicates("ref").copy()
        # if column entry is empty string, replace with UNK (can happen with normalization or lemmatization)
        mask_empty = df[column]==""
        df[column] = df[column].where(~mask_empty, other="UNK")
        # mask proper nouns
        if mask and "pos" in df.columns:
            mask_bool = df["pos"].isin(["PN", "RN", "DN", "GN", "MN", "SN", "n"])
            df[column] = df[column].where(~mask_bool, other=df["pos"])

        # change number masking from `n` to `NUM`
        # !comment out for Egyptian
        #if mask:
        #    mask_num = df[column]=="n"
        #    df[column] = df[column].where(~mask_num, other="NUM")

        # remove rows without break_perc (happens with non-Akkadian words)
        if "" in df["break_perc"].unique():
            df = df[df["break_perc"]!=""].copy()
        # filter according to break_perc
        mask_break = df["break_perc"] <= break_perc
        df[column] = df[column].where(mask_break, other="X")
        # calculate text length with and without UNK and x tokens
        text_length_full = df.shape[0]
        mask_partial = df[column].isin(["UNK", "X", "x"])
        text_length_partial = text_length_full - sum(mask_partial)
        # create text lines
        text = ""
        df_lines = split_df_by_column_value(df, "line")
        for line in df_lines:
            word_list = list(filter(None, line[column].to_list()))
            if word_list != []:
                text += " ".join(map(str, word_list)).replace("x", "X").strip() + " " #+ "\n"

        if segmentation == False:
            # remove all white spaces (word segmentation and line breaks)
            text = re.sub(r"[\s\u00A0]+", "", text)

        return (text, text_length_full, text_length_partial)

# %%
df2str(corpus[0], "lemma_id")
# Out:
# ('UNK 162450 UNK UNK UNK 851513 10030 UNK 91909 167210 UNK UNK 78900 38540 UNK 168850 94550 UNK 851513 10090 107529 850836 78870 10030 UNK UNK 162450 UNK 851512 10030 60920 78873 10120 91970 UNK 851513 UNK UNK 851513 UNK UNK 131460 78873 10030 64362 162650 UNK 851513 10090 107529 185810 400055 10030 UNK 30730 172720 500027 28550 10130 91902 UNK UNK 500024 10090 107529 185810 400055 10030 UNK 58770 UNK 28550 107529 150110 UNK 851513 10050 107529 60030 137250 91901 33120 UNK 851513 10030 UNK UNK 851513 10030 107529 94180 91903 34860 47271 UNK 851513 58770 119620 92500 10050 UNK UNK UNK 10090 UNK ',
#  105,
#  73)

# %% [markdown]
# ### To convert to specific word levels and create dictionaries

# %% [markdown]
# **Function to convert the dataframes into strings of lemmatized texts**.
# * param corpus: a list of dataframes
# * param break_perc: a parameter which dictates whether to include broken words depending on the percentage of how broken they are.
#                        Compares this value to the `break_perc` column in the dataframe.
#                        Parameter is set to 1 (i.e. all words, whether broken or not, are included); can be any float between 0 and 1.
# * param mask: boolean whether to mask named entities or not; set to True.
# * return: a dictionary where the keys are the text IDs and the values are the lemmatized texts

# %%
def get_lemmatized_texts(corpus, break_perc=1, mask=True):

    texts_dict = {}
    for df in corpus:
        # get the text number from the dataframe "text" column
        key = df["text"].iloc[0]
        text, text_length_full, text_length_partial = df2str(df, "lemma_id", break_perc, mask)
        texts_dict[key] = (text, text_length_full, text_length_partial)
    return texts_dict

# %%
get_lemmatized_texts((split_df_by_column_value(corpus[0], "text")))
# Out:
# {'2FPMTQIP45HI3LODGNIZFDO77I': ('UNK 162450 UNK UNK UNK 851513 10030 UNK 91909 167210 UNK UNK 78900 38540 UNK 168850 94550 UNK 851513 10090 107529 850836 78870 10030 UNK UNK 162450 UNK 851512 10030 60920 78873 10120 91970 UNK 851513 UNK UNK 851513 UNK UNK 131460 78873 10030 64362 162650 UNK 851513 10090 107529 185810 400055 10030 UNK 30730 172720 500027 28550 10130 91902 UNK UNK 500024 10090 107529 185810 400055 10030 UNK 58770 UNK 28550 107529 150110 UNK 851513 10050 107529 60030 137250 91901 33120 UNK 851513 10030 UNK UNK 851513 10030 107529 94180 91903 34860 47271 UNK 851513 58770 119620 92500 10050 UNK UNK UNK 10090 UNK ',
#   105,
#   73)}

# %% [markdown]
# **Function to convert the dataframes into strings of normalized texts**.
# * param corpus: a list of dataframes
# * param break_perc: a parameter which dictates whether to include broken words depending on the percentage of how broken they are.
#                        Compares this value to the `break_perc` column in the dataframe.
#                        Parameter is set to 1 (i.e. all words, whether broken or not, are included); can be any float between 0 and 1.
# * param mask: boolean whether to mask named entities or not; set to True.
# * return: a dictionary where the keys are the text IDs and the values are the normalized texts

# %%
def get_normalized_texts(corpus, break_perc=1, mask=True):

    texts_dict = {}
    for df in corpus:
        # get the text number from the dataframe "text" column
        key = df["text"].iloc[0]
        text, text_length_full, text_length_partial = df2str(df, "norm", break_perc, mask)
        texts_dict[key] = (text, text_length_full, text_length_partial)
    return texts_dict

# %%
get_normalized_texts((split_df_by_column_value(corpus[0], "text")))
# Out:
# {'2FPMTQIP45HI3LODGNIZFDO77I': ('[…] qd […] […] • ꞽw ⸗ꞽ […] r gmi̯ […] […] n ꜥnḫ […] tꜣ rmṯ.t • ꞽw ⸗s ḥr __ n ⸗ꞽ […] […] qd • ꞽw ⸗ꞽ pri̯ n ⸗t r-bw~n~r • ꞽw […] • ꞽw […] […] sbꞽ.t n ⸗ꞽ m qd • ꞽw ⸗s ḥr ḏd n ⸗ꞽ • ꞽḫ trꞽ ptꞽ ꞽrr ⸗tn r […] • ꞽ ⸗s ḥr ḏd n ⸗ꞽ […] pꜣ […] ꞽri̯.t ḥr sd.t • ꞽw ⸗f ḥr pnw snf r ꞽwtn • ꞽw ⸗ꞽ […] • ꞽw ⸗ꞽ ḥr rmi̯ r ꜥꜣ.t wr.t • ꞽw pꜣ ḫr r-ḏr ⸗f […] […] __ ⸗s […] ',
#   105,
#   105)}

# %% [markdown]
# **Function to convert the dataframes into strings of segmented unicode texts**.
# * param corpus: a list of dataframes
# * param break_perc: a parameter which dictates whether to include broken words depending on the percentage of how broken they are.
#                        Compares this value to the `break_perc` column in the dataframe.
#                        Parameter is set to 1 (i.e. all words, whether broken or not, are included); can be any float between 0 and 1.
# * param mask: boolean whether to mask named entities or not; set to True.
# * return: a dictionary where the keys are the text IDs and the values are the segmented unicode texts

# %%
def get_segmented_unicode_texts(corpus, break_perc=1, mask=True):

    texts_dict = {}
    for df in corpus:
        # get the text number from the dataframe "text" column
        key = df["text"].iloc[0]
        text, text_length_full, text_length_partial = df2str(df, "unicode_word", break_perc, mask)
        texts_dict[key] = (text, text_length_full, text_length_partial)
    return texts_dict

# %%
get_segmented_unicode_texts((split_df_by_column_value(corpus[0], "text")))
# Out:
# {'2FPMTQIP45HI3LODGNIZFDO77I': ('[…] 𓐪𓂧𓏌𓏲𓁻\U00013455 […] […] • 𓇋𓏲 𓀀 […] 𓂋 𓅠𓅓[…] […] […] 𓈖 𓋹𓈖𓐍 […] 𓏏𓄿 𓂋𓎀𓀀𓁐𓏥 • 𓇋𓏲 𓋴 𓁷𓏤 […] 𓈖 𓀀 […] […] […]𓂧\U00013455𓏌\U00013455𓏲𓁻 • 𓇋𓏲 𓀀 𓉐𓂋𓂻 𓈖 𓀀 𓂋𓃀𓏲𓈖𓏥𓂋𓈐𓂻 • 𓇋𓏲 […] • 𓇋𓏲 […] […] […]𓃀𓇋𓏏𓂻 𓈖 𓀀 𓅓 𓐪𓂧𓏌𓏲𓁻 • 𓇋𓏲 𓋴 𓁷𓏤 𓆓𓂧 𓈖 𓀀 • 𓇋𓐍𓏛 𓏏𓂋𓇋𓆵𓏛 𓊪𓏏𓇋𓀁 𓁹𓂋 𓏏𓈖𓏥 𓂋 […] • 𓇋𓀁 𓋴 𓁷𓏤 𓆓𓂧 𓈖 𓀀 […] 𓅯[…] […] 𓁹𓂋𓏏 𓁷𓏤 𓋴𓂧𓏏𓏴𓏥 • 𓇋𓏲 𓆑 UNK 𓊪𓈖𓏌𓏲𓏴𓏛𓏫 𓊃𓈖𓆑𓂐𓏥 𓂋 𓃛𓏲𓏏𓈖[…]𓈇𓏤 • 𓇋𓏲 𓀀 […] • 𓇋𓏲 𓀀 𓁷𓏤 𓂋𓅓𓏲𓁿 𓂋 𓉻𓏏𓏛 𓅨𓂋𓏏 • 𓇋𓏲 𓅯𓄿 𓐍𓂋𓏏𓉐𓏤 𓂋𓇥𓂋\U00013455 […] […] […] […]𓁻\U00013455[…]𓏫\U00013455 𓋴\U00013455 […] ',
#   105,
#   104)}

# %% [markdown]
# ### To create the vector space model

# %% [markdown]
# #### Vectorizing texts with TfidfVectorizer
#
# 🔧 What Does TfidfVectorizer Do?
#
# TfidfVectorizer is a class that:
#
#    * Reads text data
#    * Cleans and tokenizes it
#    * Builds a vocabulary
#    * Calculates TF-IDF values
#    * Returns a matrix (lokks similar to a Pandas dataframe but isn't a dataframe) where each row is a document and each column is a term

# %% [markdown]
# **Converts a list of texts into a term-document matrix based on TF-IDF scores**.
#
# Full documentation of the variables of TfidfVectorizer from sklearn, see: https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html#sklearn.feature_extraction.text.TfidfVectorizer
# * param corpus: a dataframe in which the texts are in a `"text"` column and the dataframe's index is the text ids.
# * param analyzer: whether the feature should be made of word or character n-grams.
#                      use `"word"` for word features, `"char_wb"` for character n-grams within word boundaries,
#                      or `"char"` for character n-grams without word boundaries.
# * param ngram_range: the lower and upper boundary of the range of n-values for different n-grams to be extracted.
# * param max_df: threshold to ignore terms that have a document frequency above a certain value.
#                    If the threshold is a float, it represent a proportion of the documents.
#                    If the threshold is an integer, it represents absolute counts of number of documents in which the terms appears.
# * param min_df: threshold to ignore terms that have a document frequency below a certain value.
#                    If the threshold is a float, it represent a proportion of the documents.
#                    If the threshold is an integer, it represents absolute counts of number of documents in which the terms appears.
# * param max_features: if not `None`, build a vocabulary that only considers the top max_features ordered by term frequency across the corpus.
# * param stop_words: if `None`, no stop words are used. Otherwise, can be a list with words to be removed from resulting tokens.
# * return: `counts` the raw counts of the vectorizer,
#              `counts_df` a dataframe of the counts where the index is the text ids and the columns are the tokens,
#              `stop_words` an updated list of stop words

# %% [markdown]
# ![](https://www.humanitiesdataanalysis.org/_images/bow.png)

# %% [markdown]
# **Figure 1**. Example of a document-term matrix extracted from a corpus, see Fig. 3 in Karsdorp, F., Kestemont, M., & Riddell, A. (2021). Humanities Data Analysis: Case Studies
# with Python. Princeton University Press.

# %%
def vectorize(corpus, analyzer="word", ngram_range=(1,1), max_df=1.0, min_df=1, max_features=None, stop_words=["UNK", "X"]):

    vectorizer = TfidfVectorizer(input="content", lowercase=False, analyzer=analyzer,
                                 # RegEx for Akkadian
                                 #token_pattern=r"(?u)\b\w+\b", ngram_range=ngram_range,
                                 # RegEx for Egyptian
                                 token_pattern=r"(?u)\b[\w\.]+\b", ngram_range=ngram_range,
                                 max_df=max_df, min_df=min_df, max_features=max_features, stop_words=stop_words)

    counts = vectorizer.fit_transform(corpus["text"].tolist()).toarray()
    #stop_words = vectorizer.stop_words_ # use when stop_words are not defined in the parameters

    # saving the vocab used for vectorization, and switching the dictionary so that the feature index is the key
    vocab = vectorizer.vocabulary_
    switched_vocab = {value: key for key, value in vocab.items()}
    # adding the vocab words to the counts dataframe for easier viewing.
    column_names = []
    x = 0
    while x < len(switched_vocab):
        column_names.append(switched_vocab[x])
        x += 1

    counts_df = pd.DataFrame(counts, index=corpus.index, columns=column_names)

    return (counts, counts_df, stop_words)

# %% [markdown]
# #### Calculating distances between vectorized documents

# %% [markdown]
# **Converts a term-document matrix to a text similarity matrix**.
# * param counts: the raw counts from the `vectorize` function.
# * param metric: the metric by which to calculate the distances between the texts in the corpus. For one place to look into the different types of matrics see "Computing distances between documents" in [Karsdrop, Kestemont, & Riddell 2021](https://www.humanitiesdataanalysis.org/vector-space-model/notebook.html#computing-distances-between-documents)
#                    Valid metrics are:
#                    ‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’,
#                    ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulczynski1’,
#                    ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’,
#                    ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’.
# * param text_ids: list of unique text_ids.
# * return: a dataframe matrix of distance between texts.

# %%
def distance_calculator(counts, metric, text_ids):

    return pd.DataFrame(squareform(pdist(counts, metric=metric)), index=text_ids, columns=text_ids)

# %% [markdown]
# #### reducing dimensions with pca or tsne

# %% [markdown]
# **Reduces multidimensional data into two dimensions using PCA**.
# * param df: dataframe holding the dimensions to reduce. All columns should include numerical values only.
#                The dataframe's index should hold the unique text ids.
# * param metadata: the rest of the metadata in the corpus, to help visualize the resulting clusters in meaningful ways.
#                      The metadata's index should hold the unique text ids.
# * return: a dataframe with the coordinates of the two remaining dimensions on all other columns from the metadata.

# %%
def reduce_dimensions_pca(df, metadata):

    pca = PCA(n_components=2)
    reduced_data = pca.fit_transform(df)
    reduced_df = pd.DataFrame(data=reduced_data, index=df.index, columns=["component 1", "component 2"])
    reduced_df_metadata = metadata.join(reduced_df)
    return reduced_df_metadata

# %% [markdown]
# **Reduces multidimensional data into two dimensions using TSNE**.
#
# See full documentation of sklearn's TSNE on: https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html
# * param df: dataframe holding the dimensions to reduce. All columns should include numerical values only.
#                The dataframe's index should hold the unique text ids.
# * param perplexity: perplexity is a measure the weighs the importance of nearby versus distant points when creating a lower-dimension mapping.
#                        t-SNE first converts the distances between points into conditional probabilities that represent similarities,
#                        using Gaussian probability distributions.
#                        The perplexity parameter influences the variance used to compute these probabilities.
#                        A higher perplexity leads to a broader Gaussian that considers a larger number of neighbors when assessing similarity.
#                        Lower perplexity puts more focus on the local structure and considers fewer neighbors.
#                        A good perplexity depends greatly on dataset size and density.
#                        The documentation recommends a value between 5 and 50.
#                        We recommend to start with the square root of the length of the corpus.
# * param n_iter: maximum number of iterations for optimization.
# * param metric: the metric to be used when calculating distances between vectors.
#                    Valid metrics are:
#                    ‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’,
#                    ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulczynski1’,
#                    ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’,
#                    ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’.
# * param metadata: the rest of the metadata in the corpus, to help visualize the resulting clusters in meaningful ways.
#                      The metadata's index should hold the unique text ids.
# * return: a dataframe with the coordinates of the two remaining dimensions on all other columns from the metadata.

# %%
def reduce_dimensions_tsne(df, perplexity, n_iter, metric, metadata):

    tsne = TSNE(n_components=2, perplexity=perplexity, n_iter=n_iter, metric=metric, init="pca")
    reduced_data = tsne.fit_transform(df)
    reduced_df = pd.DataFrame(data=reduced_data, index=df.index, columns=["component 1", "component 2"])
    reduced_df_metadata = metadata.join(reduced_df)
    return reduced_df_metadata

# %% [markdown]
# ## Process texts from dataframes and combine results with metadata dataframe

# %%
# Function to combine processed texts with metadata

def get_corpus_metadata(texts_dict, metadata):
  texts_df = pd.DataFrame(texts_dict, index=["text", "full_length", "partial_length"]).transpose()
  df = metadata.join(texts_df)
  return df

# %%
## vectorize lemma forms
corpus_dict = get_lemmatized_texts(corpus, break_perc=0)
## vectorize normalized forms
#corpus_dict = get_normalized_texts(corpus, break_perc=0)
## vectorize Unicode cuneiform
#corpus_dict = get_segmented_unicode_texts(corpus, break_perc=0)

corpus_metadata = get_corpus_metadata(corpus_dict, metadata)

## For Akkadian
## remove texts which have less than n words excluding UNK and X
#n = 10
#print(f"Number of texts before filtering: {corpus_metadata.shape[0]}")
#corpus_metadata = corpus_metadata[corpus_metadata["partial_length"]>=n]
#print(f"Number of texts after filtering: {corpus_metadata.shape[0]}")


# For Egyptian use this instead, reset the index
n = 150
print(f"Number of texts before filtering: {corpus_metadata.shape[0]}")
corpus_metadata = corpus_metadata[corpus_metadata["partial_length"]>=n].set_index("text_name")
print(f"Number of texts after filtering: {corpus_metadata.shape[0]}")
# Out:
# Number of texts before filtering: 209
# Number of texts after filtering: 76

# %%
corpus_metadata
# Out:
#                                                    corpus_manual  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek   Erzählungen
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext          Lehren
# hintere Innenwand || Das Buch von der Himmelsku...   Erzählungen
# KV 17: Grab Sethos' I., vordere rechte Seitenka...   Erzählungen
# pWestcar = pBerlin P 3033 || Die Erzählungen de...   Erzählungen
# ...                                                          ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...        Lehren
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...        Lehren
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...        Lehren
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...   Erzählungen
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...   Erzählungen
#
#                                                                                                  path  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  sawlit || Literarische Texte || 1. Erzählungen...
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    sawlit || Literarische Texte || 3. Weisheitsle...
# hintere Innenwand || Das Buch von der Himmelsku...  sawlit || Literarische Texte || 1. Erzählungen...
# KV 17: Grab Sethos' I., vordere rechte Seitenka...  sawlit || Literarische Texte || 1. Erzählungen...
# pWestcar = pBerlin P 3033 || Die Erzählungen de...  sawlit || Literarische Texte || 1. Erzählungen...
# ...                                                                                               ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...  sawlit || Literarische Texte || 3. Weisheitsle...
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...  sawlit || Literarische Texte || 3. Weisheitsle...
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...  sawlit || Literarische Texte || 3. Weisheitsle...
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...  sawlit || Literarische Texte || 1. Erzählungen...
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...  sawlit || Literarische Texte || 1. Erzählungen...
#
#                                                    dateEarliest dateLatest  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext
# hintere Innenwand || Das Buch von der Himmelsku...
# KV 17: Grab Sethos' I., vordere rechte Seitenka...
# pWestcar = pBerlin P 3033 || Die Erzählungen de...
# ...                                                         ...        ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...
#
#                                                         language_manual  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek        Frühdemotisch
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext          Frühdemotisch
# hintere Innenwand || Das Buch von der Himmelsku...      Mittelägyptisch
# KV 17: Grab Sethos' I., vordere rechte Seitenka...      Mittelägyptisch
# pWestcar = pBerlin P 3033 || Die Erzählungen de...      Mittelägyptisch
# ...                                                                 ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...      Mittelägyptisch
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...      Mittelägyptisch
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...      Mittelägyptisch
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...  Traditionsägyptisch
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...  Traditionsägyptisch
#
#                                                                            tlaTextLangName  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek                           Frühdemotisch
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext                             Frühdemotisch
# hintere Innenwand || Das Buch von der Himmelsku...  frühes und klassisches Mittelägyptisch
# KV 17: Grab Sethos' I., vordere rechte Seitenka...  frühes und klassisches Mittelägyptisch
# pWestcar = pBerlin P 3033 || Die Erzählungen de...  frühes und klassisches Mittelägyptisch
# ...                                                                                    ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...          traditionelles Mittelägyptisch
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...          traditionelles Mittelägyptisch
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...          traditionelles Mittelägyptisch
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...          traditionelles Mittelägyptisch
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...          traditionelles Mittelägyptisch
#
#                                                                 tlaTextScriptName  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek    Späthieratische Buchschrift
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext      Späthieratische Buchschrift
# hintere Innenwand || Das Buch von der Himmelsku...   reguläre Hieroglyphenschrift
# KV 17: Grab Sethos' I., vordere rechte Seitenka...   reguläre Hieroglyphenschrift
# pWestcar = pBerlin P 3033 || Die Erzählungen de...  Mittelhieratische Buchschrift
# ...                                                                           ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...     Neuhieratische Buchschrift
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...     Neuhieratische Buchschrift
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...     Neuhieratische Buchschrift
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...    Späthieratische Buchschrift
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...   reguläre Hieroglyphenschrift
#
#                                                                                          contributors  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'J...
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    ['Peter Dils', 'Altägyptisches Wörterbuch', 'L...
# hintere Innenwand || Das Buch von der Himmelsku...  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'J...
# KV 17: Grab Sethos' I., vordere rechte Seitenka...  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'J...
# pWestcar = pBerlin P 3033 || Die Erzählungen de...  ['Verena Lepper', 'Altägyptisches Wörterbuch',...
# ...                                                                                               ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...  ['Peter Dils', 'Altägyptisches Wörterbuch', 'B...
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...  ['Peter Dils', 'Altägyptisches Wörterbuch', 'B...
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...  ['Peter Dils', 'Altägyptisches Wörterbuch', 'B...
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...  ['Peter Dils', 'Altägyptisches Wörterbuch', 'F...
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...  ['Lutz Popko', 'Altägyptisches Wörterbuch', 'J...
#
#                                                                                                  text  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  28160 600043 550055 X 64365 58770 X 78900 8806...
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    X X 851523 116230 X X X 78030 55210 X X X 1672...
# hintere Innenwand || Das Buch von der Himmelsku...  79090 116800 400007 94530 90260 203 69320 4000...
# KV 17: Grab Sethos' I., vordere rechte Seitenka...  X X X X X 500388 400151 400006 10050 64360 880...
# pWestcar = pBerlin P 3033 || Die Erzählungen de...  X X X X 79800 X X X X X X X X X X 180600 85081...
# ...                                                                                               ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...  X X X X X X X 27180 UNK 851222 179020 91900 10...
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...  64440 10110 96700 10030 851182 400090 42490 90...
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...  X X X UNK 54605 129490 91904 125370 UNK 67370 ...
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...  X X X X X 400043 X X 10050 107529 77540 X X X ...
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...  850566 90360 400833 850566 90360 400833 860011...
#
#                                                    full_length partial_length
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek        3393           1811
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext          2647           1857
# hintere Innenwand || Das Buch von der Himmelsku...         234            225
# KV 17: Grab Sethos' I., vordere rechte Seitenka...        2166           1942
# pWestcar = pBerlin P 3033 || Die Erzählungen de...        3373           2675
# ...                                                        ...            ...
# 11. pAnastasi VII = pBM EA 10222 || Kol. 1-7: D...        1283            644
# 13. tLouvre N 693 || Die Lehre des Cheti 13.4-2...         673            208
# 14. oBM EA 29550 + oDeM 1546 || Die Lehre des C...         393            248
# 03. pChassinat I = pLouvre E 25351 || Die Gesch...         331            254
# Stele Louvre C 284 ("Bentresch-Stele") || Stele...         933            904
#
# [76 rows x 11 columns]

# %% [markdown]
# # Exploring the Akkadian RINAP or Egyptian TLA Corpus using the Vector Space Model

# %%
# vectorize corpus
counts, counts_df, stop_words = vectorize(corpus_metadata, max_features=50)

# %%
counts_df.head(3)
# Out:
#                                                        10030     10050  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.304331  0.496601
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.005858  0.650786
# hintere Innenwand || Das Buch von der Himmelsku...  0.035838  0.723833
#
#                                                        10090     10100  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.069377  0.000000
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.118862  0.003428
# hintere Innenwand || Das Buch von der Himmelsku...  0.045445  0.251619
#
#                                                        10110   104690  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.172906  0.00000
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.228347  0.00512
# hintere Innenwand || Das Buch von der Himmelsku...  0.113260  0.00000
#
#                                                       107529    116230  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.087301  0.053468
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.009755  0.041986
# hintere Innenwand || Das Buch von der Himmelsku...  0.000000  0.046698
#
#                                                       129490    168850  ...  \
# text_name                                                               ...
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.028009  0.043966  ...
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.023994  0.096848  ...
# hintere Innenwand || Das Buch von der Himmelsku...  0.083873  0.000000  ...
#
#                                                       850814   851173  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.023544  0.01853
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.020168  0.00000
# hintere Innenwand || Das Buch von der Himmelsku...  0.000000  0.00000
#
#                                                       851512   851513  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.227131  0.04193
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.317453  0.00000
# hintere Innenwand || Das Buch von der Himmelsku...  0.000000  0.00000
#
#                                                       851515     90260  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.000000  0.012004
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.000000  0.034277
# hintere Innenwand || Das Buch von der Himmelsku...  0.112383  0.209682
#
#                                                        91901     91907  \
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.135032  0.276963
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.018758  0.016362
# hintere Innenwand || Das Buch von der Himmelsku...  0.152997  0.000000
#
#                                                        91909     96700
# text_name
# pVandier = pLille 139 || Recto: Meryre und Sisobek  0.033316  0.027641
# pBrooklyn 47.218.135 || Brooklyner Weisheitstext    0.017837  0.023678
# hintere Innenwand || Das Buch von der Himmelsku...  0.000000  0.082770
#
# [3 rows x 50 columns]

# %%
# calculate distance between vectorized texts
"""
Available distance metrics are:
  ‘braycurtis’, ‘canberra’, ‘chebyshev’, ‘cityblock’, ‘correlation’, ‘cosine’,
  ‘dice’, ‘euclidean’, ‘hamming’, ‘jaccard’, ‘jensenshannon’, ‘kulczynski1’,
  ‘mahalanobis’, ‘matching’, ‘minkowski’, ‘rogerstanimoto’, ‘russellrao’,
  ‘seuclidean’, ‘sokalmichener’, ‘sokalsneath’, ‘sqeuclidean’, ‘yule’.
"""
#matrix = distance_calculator(counts, "cityblock", corpus_metadata.index)
matrix = distance_calculator(counts, "cosine", corpus_metadata.index)

# Show the values of the matrix
#matrix

# Remove the digonal of the matrix as it contains distances being zero.
arr = matrix.values
arr_no_diag = arr[~np.eye(arr.shape[0], dtype=bool)]
# Flatten for ...
arr_no_diag.flatten()
# ... sorting to determine smallest and largest distances later.
arr_no_diag.sort()
#print(arr_no_diag)

# Plot the histogram of the flattend matrix
import matplotlib.pyplot as plt
plt.hist(arr_no_diag,bins=76) # 76 bins or less because there are 76 Documents

# Minimum/smallest distance
min_value = arr_no_diag[0]
min_location = (matrix == min_value)
# Get row and column index for the smallest distance
row_idx, col_name = min_location.stack().idxmax()
print(f"\nSmallest distance between documents: {min_value}\nRow: {row_idx}\nCol: '{col_name}'\n")

# Maximum/largest distance
max_value = arr_no_diag[-1]
max_location = (matrix == max_value)
# Get row and column index for the smallest distance
row_idx, col_name = max_location.stack().idxmax()
print(f"Largest distance between documents: {max_value}\nRow: {row_idx}\nCol: '{col_name}'\n")
# Out:
# Smallest distance between documents: 0.008462072744650606
# Row: pBerlin P 3022 und Fragmente pAmherst m-q (B) || Sinuhe Koch 04-81
# Col: 'oAshmolean Museum 1945.40 aus Deir el Medineh (AOS) || Sinuhe Koch 01-79'
#
# Largest distance between documents: 0.9563024977788583
# Row: pKahun VI.12 = pUC 32158+32150A+32148B || Recto: Die Geschichte von Horus und Seth
# Col: 'pLouvre N 3136 || Kriegsgeschichte Ramses' III.'

# %%
# visualize matrix
fig = px.imshow(matrix)

# adjust size of the matrix
fig.update_layout(
    autosize=False,
    width=1500,
    height=1500,
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b5020a0f-0a9b-4a92-ba57-21ed331d1126" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5020a0f-0a9b-4a92-ba57-21ed331d1126")) {                    Plotly.newPlot(                        "b5020a0f-0a9b-4a92-ba57-21ed331d1126",                        [{"coloraxis":"coloraxis","name":"0","x":["pVandier = pLille 139 || Recto: Meryre und Sisobek","pBrooklyn 47.218.135 || Brooklyner Weisheitstext","hintere Innenwand || Das Buch von der Himmelskuh (oder: Die Vernichtung des Menschengeschlechts)","KV 17: Grab Sethos' I., vordere rechte Seitenkammer der Sargkammer || Das Buch von der Himmelskuh (oder: Die Vernichtung des Menschengeschlechts)","pWestcar = pBerlin P 3033 || Die Erzählungen des pWestcar","pPetersburg 1115 || Die Geschichte des Schiffbrüchigen","pBerlin P 3022 und Fragmente pAmherst m-q (B) || Sinuhe Koch 04-81","pKahun VI.12 = pUC 32158+32150A+32148B || Recto: Die Geschichte von Horus und Seth","pBerlin P 3024 || Die Hirtengeschichte","pMoskau o.Nr. + pMoskau 167 || Mythologische Geschichte","pBerlin P 3023 + pAmherst I (Bauer, B1) || Der beredte Bauer (Version B1)","pBerlin P 3025 + pAmherst II (Bauer, B2) || Der beredte Bauer (Version B2)","pRamesseum A = pBerlin P 10499 (Bauer, R) || Recto: Der beredte Bauer (Version R)","pLeiden I 344 = AMS 27 || Recto: Admonitions = Ipuwer","pAmherst 3 + pBerlin P 3024 || Der Lebensmüde","tBM EA 5645 || Die Klagen des Chacheperreseneb","pPetersburg 1116 B || Verso: Die Prophezeiungen des Neferti","pRamesseum I = pBM EA 10754 || Die Rede des Sasobek","pButler = pBM EA 10274 || Verso: Die Rede des Vogelfängers Juru","pMoskau o.Nr. (Pleasures of Fishing) || The Pleasures of Fishing and Fowling","pMoskau o.Nr. (Sporting King) || The Sporting King","pMillingen || Die Lehre des Amenemhet","pRamesseum II = pBM EA 10755 || Die Lehre des pRamesseum II","pBM EA 10371+10435 (Ptahhotep, Version L1) || Die Lehre des Ptahhotep (Version L1)","pBM EA 10509 (Ptahhotep, Version L2+L2G) || Die Lehre des Ptahhotep (Version L2+L2G)","pPrisse = pBN 186-194 (Ptahhotep, Version P) || Die Lehre des Ptahhotep","tCarnarvon 1 || Verso: Die Lehre des Ptahhotep (Version C)","pPrisse = pBN 183 (Kagemni) || Kol. 1-2: Die Lehre für Kagemni","pCarlsberg VI || Die Lehre für Merikare","pMoskau 4658 || Die Lehre für Merikare","pPetersburg 1116 A || Verso: Die Lehre für Merikare","01. sKairo CG 20538 des Sehetep-ib-Re || Die Loyalistische Lehre des Kairsu 1.1-6.10","03. pLouvre E 4864 || Recto: Die Loyalistische Lehre des Kairsu 3.6-14.11","04. tCarnarvon 2 || Verso: Die Loyalistische Lehre des Kairsu 8.1-14.12","08. oAshmolean 1938.912 || Die Loyalistische Lehre des Kairsu 5.1-8.1","pSallier I = pBM EA 10185 || Recto 1-3: Apophis und Seqenenre","Topf 1: oTurin Suppl. 6619 + oGardiner 306 + oDeM 1251 I+II + oTurin Suppl. 6806 || Chonsemhab und der Geist, Kolumne 2","Topf 2: oTurin Cat. 6620+6838 + oDeM 1252 I+II + oTurin Cat. 6851 + oFlorenz 2617 || Chonsemhab und der Geist, Kolumne 3","Topf 2: oFlorenz 2616 || Chonsemhab und der Geist, Kolumne 3","pd’Orbiney = pBM EA 10183 || Recto: Das Zweibrüdermärchen","tTurin Cat. 6238 = tTurin CGT 58004 || Der Streit zwischen Kopf und Leib","pBN 202 + pAmherst 9 || Die Götter und das Meer (\"Astartelegende\")","pMoskau 120 || Recto: Die Reise des Wenamun","pTurin CGT 54033 (alias: pTurin CGT 54031) || Verso: Erzählung von einem Götterstreit","pBoulaq 13 = pCairo CG 58041 || Eine Kriminalgeschichte (?)","pBerlin P 3020 + pWien 36 || Erzählung von einem König und einer Göttin","pDeM 39 || Herischef und General Meryre","pHarris 500 = pBM EA 10060 || Verso 1-3: Die Einnahme von Joppe","pHarris 500 = pBM EA 10060 || Verso 4-8: Das Prinzenmärchen","pLouvre N 3136 || Kriegsgesc ...

# %%
# reduce matrix dimensions
reduced_tsne = reduce_dimensions_tsne(matrix, perplexity=matrix.shape[0]**0.5, n_iter=5000, metric="euclidean", metadata=corpus_metadata)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning:
#
# 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.

# %%
# visualize reduced dimensions

# adjust size column for visualization
size_min = 3
size_max = 70
size = (reduced_tsne["partial_length"] / reduced_tsne["partial_length"].max() * (size_max - size_min) + size_min).tolist()

# create figure
# for Akkadian use symbol = "script", color="project",
# for Egyptian
fig = px.scatter(reduced_tsne, x="component 1", y="component 2", size=size, symbol = "corpus_manual", color="language_manual", hover_data=["partial_length", "full_length", reduced_tsne.index])
fig.update_traces(marker=dict(line=dict(width=1, color='black')))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="004985b1-9a91-4963-8590-8c753e9b5b2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("004985b1-9a91-4963-8590-8c753e9b5b2e")) {                    Plotly.newPlot(                        "004985b1-9a91-4963-8590-8c753e9b5b2e",                        [{"customdata":[[1811,3393,"pVandier = pLille 139 || Recto: Meryre und Sisobek"]],"hovertemplate":"language_manual=Frühdemotisch\u003cbr\u003ecorpus_manual=Erzählungen\u003cbr\u003ecomponent 1=%{x}\u003cbr\u003ecomponent 2=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003epartial_length=%{customdata[0]}\u003cbr\u003efull_length=%{customdata[1]}\u003cbr\u003etext_name=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Frühdemotisch, Erzählungen","marker":{"color":"#636efa","size":[28.68522438611346],"sizemode":"area","sizeref":0.175,"symbol":"circle","line":{"color":"black","width":1}},"mode":"markers","name":"Frühdemotisch, Erzählungen","orientation":"v","showlegend":true,"x":[9.113264],"xaxis":"x","y":[-26.284502],"yaxis":"y","type":"scatter"},{"customdata":[[1857,2647,"pBrooklyn 47.218.135 || Brooklyner Weisheitstext"]],"hovertemplate":"language_manual=Frühdemotisch\u003cbr\u003ecorpus_manual=Lehren\u003cbr\u003ecomponent 1=%{x}\u003cbr\u003ecomponent 2=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003epartial_length=%{customdata[0]}\u003cbr\u003efull_length=%{customdata[1]}\u003cbr\u003etext_name=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Frühdemotisch, Lehren","marker":{"color":"#636efa","size":[29.337637595258258],"sizemode":"area","sizeref":0.175,"symbol":"diamond","line":{"color":"black","width":1}},"mode":"markers","name":"Frühdemotisch, Lehren","orientation":"v","showlegend":true,"x":[7.581783],"xaxis":"x","y":[-22.517807],"yaxis":"y","type":"scatter"},{"customdata":[[225,234,"hintere Innenwand || Das Buch von der Himmelskuh (oder: Die Vernichtung des Menschengeschlechts)"],[1942,2166,"KV 17: Grab Sethos' I., vordere rechte Seitenkammer der Sargkammer || Das Buch von der Himmelskuh (oder: Die Vernichtung des Menschengeschlechts)"],[2675,3373,"pWestcar = pBerlin P 3033 || Die Erzählungen des pWestcar"],[1270,1278,"pPetersburg 1115 || Die Geschichte des Schiffbrüchigen"],[3176,3251,"pBerlin P 3022 und Fragmente pAmherst m-q (B) || Sinuhe Koch 04-81"],[199,304,"pKahun VI.12 = pUC 32158+32150A+32148B || Recto: Die Geschichte von Horus und Seth"],[175,181,"pBerlin P 3024 || Die Hirtengeschichte"],[644,1497,"pMoskau o.Nr. + pMoskau 167 || Mythologische Geschichte"],[744,1283,"pBerlin P 10499 aus Theben-West (R) || Verso: Sinuhe Koch 01-58"],[2389,3415,"oAshmolean Museum 1945.40 aus Deir el Medineh (AOS) || Sinuhe Koch 01-79"],[403,523,"oKairo CG 25216 aus dem Grab des Sennedjem TT 1 (C) || Recto Sinuhe Koch 01-22"],[152,459,"pMoskau 4657 (Golenischeff) (G) || Sinuhe Koch 01-37"]],"hovertemplate":"language_manual=Mittelägyptisch\u003cbr\u003ecorpus_manual=Erzählungen\u003cbr\u003ecomponent 1=%{x}\u003cbr\u003ecomponent 2=%{y}\u003cbr\u003esize=%{marker.size}\u003cbr\u003epartial_length=%{customdata[0]}\u003cbr\u003efull_length=%{customdata[1]}\u003cbr\u003etext_name=%{customdata[2]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mittelägyptisch, Erzählungen","marker":{"color":"#EF553B","size":[6.1911515664690935,30.543183742591026,40.93924640135478,21.012277730736663,48.04487722269263,5.8223962743437765,5.482006773920406,12.133784928027096,13.55207451312447,36.88293818797629,8.715707027942422,5.15580016934801],"sizemode":"area","sizeref":0.175,"symbol":"circle","line":{"color":"black","width":1}},"mode":"markers","name":"Mittelägyptisch, Erzählungen","orientation":"v","showlegend":true,"x":[-28.258112,-9.184674 ...

# %% [markdown]
# # Find Shared Tokens

# %% [markdown]
# **creates a mini df that includes only the chosen text and the shared tokens in those texts**
#   (i.e., all tokens that are none zero in all texts).
# * param df: the counts_df where the index is the text ids and the columns are the tokens.
# * param text_ids: a list containing text ids.
# * return: a dataframe where the index are the shared tokens and the columns are the texts.
#            the values are the tf-idf scores.

# %%
def find_shared_tokens(df, text_ids):

  mini_df = df[df.index.isin(text_ids)].copy()
  mini_df = mini_df.loc[:, (mini_df != 0).all(axis=0)].copy()
  return mini_df.transpose()

# %%
# Akkadian
#shared_tokens = find_shared_tokens(counts_df, ["Q003450", "Q003711", "Q003790"])
# Egyptian
shared_tokens = find_shared_tokens(counts_df, ["pBerlin P 3023 + pAmherst I (Bauer, B1) || Der beredte Bauer (Version B1)", "pBerlin P 3025 + pAmherst II (Bauer, B2) || Der beredte Bauer (Version B2)", "pPetersburg 1116 A || Verso: Die Lehre für Merikare", "pBM EA 10509 (Ptahhotep, Version L2+L2G) || Die Lehre des Ptahhotep (Version L2+L2G)"])#, "3RU7Z4VQ45CYFIQ4PUGQ3HDJFU"])

shared_tokens
# Out:
# text_name  pBerlin P 3023 + pAmherst I (Bauer, B1) || Der beredte Bauer (Version B1)  \
# 10030                                               0.157330
# 10050                                               0.519172
# 10090                                               0.106631
# 10100                                               0.025393
# 10110                                               0.580085
# 107529                                              0.084310
# 116230                                              0.038881
# 129490                                              0.028568
# 170100                                              0.042376
# 185810                                              0.105795
# 21930                                               0.085993
# 23290                                               0.062768
# 26870                                               0.026517
# 28550                                               0.127491
# 400007                                              0.086306
# 400055                                              0.166510
# 400082                                              0.058129
# 400090                                              0.068914
# 500292                                              0.097629
# 550028                                              0.059464
# 59741                                               0.183034
# 64360                                               0.003011
# 64364                                               0.048896
# 64410                                               0.115666
# 64440                                               0.130205
# 78873                                               0.020920
# 78890                                               0.123866
# 79800                                               0.287411
# 81650                                               0.075105
# 81660                                               0.042713
# 84550                                               0.147736
# 91901                                               0.060797
# 91907                                               0.041669
# 96700                                               0.046987
#
# text_name  pBerlin P 3025 + pAmherst II (Bauer, B2) || Der beredte Bauer (Version B2)  \
# 10030                                               0.188642
# 10050                                               0.453580
# 10090                                               0.068346
# 10100                                               0.007884
# 10110                                               0.560686
# 107529                                              0.037393
# 116230                                              0.079010
# 129490                                              0.023651
# 170100                                              0.032385
# 185810                                              0.062233
# 21930                                               0.068346
# 23290                                               0.049230
# 26870                                               0.047042
# 28550                                               0.101058
# 400007                                              0.103721
# 400055                                              0.144417
# 400082                                              0.054140
# 400090                                              0.031120
# 500292                                              0.060620
# 550028                                              0.057435
# 59741                                               0.111330
# 64360                                               0.007479
# 64364                                               0.032385
# 64410                                               0.179549
# 64440                                               0.030318
# 78873                                               0.034640
# 78890                                               0.317900
# 79800                                               0.213331
# 81650                                               0.058907
# 81660                                               0.037887
# 84550                                               0.141127
# 91901                                               0.057524
# 91907                                               0.094084
# 96700                                               0.015560
#
# text_name  pBM EA 10509 (Ptahhotep, Version L2+L2G) || Die Lehre des Ptahhotep (Version L2+L2G)  \
# 10030                                               0.058477
# 10050                                               0.574471
# 10090                                               0.158898
# 10100                                               0.043989
# 10110                                               0.598422
# 107529                                              0.037092
# 116230                                              0.070755
# 129490                                              0.073316
# 170100                                              0.085330
# 185810                                              0.102888
# 21930                                               0.037076
# 23290                                               0.167869
# 26870                                               0.023332
# 28550                                               0.142015
# 400007                                              0.128610
# 400055                                              0.199420
# 400082                                              0.033566
# 400090                                              0.019294
# 500292                                              0.131541
# 550028                                              0.010174
# 59741                                               0.143797
# 64360                                               0.013910
# 64364                                               0.040155
# 64410                                               0.192949
# 64440                                               0.012531
# 78873                                               0.005369
# 78890                                               0.101724
# 79800                                               0.193304
# 81650                                               0.042608
# 81660                                               0.056375
# 84550                                               0.052497
# 91901                                               0.049038
# 91907                                               0.023332
# 96700                                               0.057881
#
# text_name  pPetersburg 1116 A || Verso: Die Lehre für Merikare
# 10030                                               0.166318
# 10050                                               0.547236
# 10090                                               0.210901
# 10100                                               0.133161
# 10110                                               0.474904
# 107529                                              0.024292
# 116230                                              0.051328
# 129490                                              0.081945
# 170100                                              0.021038
# 185810                                              0.053906
# 21930                                               0.072151
# 23290                                               0.069295
# 26870                                               0.012224
# 28550                                               0.231970
# 400007                                              0.148240
# 400055                                              0.187639
# 400082                                              0.058620
# 400090                                              0.096030
# 500292                                              0.054149
# 550028                                              0.015991
# 59741                                               0.223003
# 64360                                               0.082593
# 64364                                               0.147269
# 64410                                               0.124419
# 64440                                               0.059087
# 78873                                               0.033755
# 78890                                               0.153226
# 79800                                               0.213215
# 81650                                               0.076537
# 81660                                               0.054149
# 84550                                               0.116131
# 91901                                               0.065398
# 91907                                               0.030561
# 96700                                               0.055597

# %%
px.scatter(shared_tokens)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ffe667b3-e249-400b-aed0-fd58c33383f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffe667b3-e249-400b-aed0-fd58c33383f3")) {                    Plotly.newPlot(                        "ffe667b3-e249-400b-aed0-fd58c33383f3",                        [{"hovertemplate":"text_name=pBerlin P 3023 + pAmherst I (Bauer, B1) || Der beredte Bauer (Version B1)\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pBerlin P 3023 + pAmherst I (Bauer, B1) || Der beredte Bauer (Version B1)","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"pBerlin P 3023 + pAmherst I (Bauer, B1) || Der beredte Bauer (Version B1)","orientation":"v","showlegend":true,"x":["10030","10050","10090","10100","10110","107529","116230","129490","170100","185810","21930","23290","26870","28550","400007","400055","400082","400090","500292","550028","59741","64360","64364","64410","64440","78873","78890","79800","81650","81660","84550","91901","91907","96700"],"xaxis":"x","y":[0.15732992636115237,0.5191723237436823,0.10663138345393701,0.025393444398454354,0.5800849771237776,0.08430998256831916,0.038880619991621894,0.028567624948261146,0.042376439562724647,0.10579451900136755,0.08599305117252987,0.06276791197625986,0.026516650427862252,0.12749149205127863,0.08630605497479983,0.16650962895754684,0.05812900465883961,0.0689136175392393,0.09762887065408671,0.05946433766171987,0.1830339115945656,0.003011070806011399,0.04889589180314382,0.11566624194861794,0.13020451903835456,0.020920383820267886,0.12386606146254754,0.28741096536497934,0.07510549412123588,0.04271263091116293,0.1477356238123754,0.06079710691500095,0.04166902210092639,0.046986557413117705],"yaxis":"y","type":"scatter"},{"hovertemplate":"text_name=pBerlin P 3025 + pAmherst II (Bauer, B2) || Der beredte Bauer (Version B2)\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pBerlin P 3025 + pAmherst II (Bauer, B2) || Der beredte Bauer (Version B2)","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"pBerlin P 3025 + pAmherst II (Bauer, B2) || Der beredte Bauer (Version B2)","orientation":"v","showlegend":true,"x":["10030","10050","10090","10100","10110","107529","116230","129490","170100","185810","21930","23290","26870","28550","400007","400055","400082","400090","500292","550028","59741","64360","64364","64410","64440","78873","78890","79800","81650","81660","84550","91901","91907","96700"],"xaxis":"x","y":[0.18864216926417268,0.45358000470462184,0.06834562852155097,0.007883680779994549,0.5606864703454945,0.03739283362756359,0.07900969959998903,0.023651042339983643,0.03238459786228196,0.06223282071448865,0.06834562852155097,0.04923032874813854,0.04704224423274406,0.10105830496294964,0.1037213678574811,0.14441718956450997,0.05414041233614625,0.03112001255408138,0.060619964670491536,0.05743538353949496,0.11133049288770688,0.007478566725512718,0.03238459786228196,0.17954943690112835,0.030317594418392206,0.034639833335671215,0.31789973983748127,0.21333142457526702,0.058906980493126634,0.03788747791905721,0.14112673269823217,0.05752425601255803,0.09408448846548811,0.01556000627704069],"yaxis":"y","type":"scatter"},{"hovertemplate":"text_name=pBM EA 10509 (Ptahhotep, Version L2+L2G) || Die Lehre des Ptahhotep (Version L2+L2G)\u003cbr\u003eindex=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"pBM EA 10509 (Ptahhotep, Version L2+L2G) || Die Lehre des Ptahhotep (Version L2+L2G)","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"pBM EA 10509 (Ptahhotep, Version L2+L2G) || Die Lehre des Ptahhotep (Version L2+L2G)","o ...

# %% [markdown]
# *This notebook was created by [Avital Romach](https://github.com/ARomach), with additional code and text by [Eliese-Sophia Lincke](https://www.geschkult.fu-berlin.de/e/aegyptologie/personen/Professorinnen-und-Professoren/Lincke/index.html), [Shai Gordin](https://digitalpasts.github.io/) and [Daniel A. Werning](https://www.bbaw.de/die-akademie/mitarbeiterinnen-mitarbeiter/werning-daniel) in Spring 2024 for the course [Ancient Language Processing](https://digitalpasts.github.io/ALP-course/). Code can be reused under a [CC-BY 4.0](https://creativecommons.org/licenses/by/4.0/)*
